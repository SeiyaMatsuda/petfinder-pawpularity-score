# %%
import sys
sys.path.append('../')

# %%
import numpy as np, pandas as pd
from glob import glob
import shutil, os
import pickle
import matplotlib.pyplot as plt
from sklearn.model_selection import GroupKFold
from sklearn.decomposition import IncrementalPCA
from tqdm.notebook import tqdm
import seaborn as sns
import PIL.Image as Image
import torch
from torch.utils.data import Dataset, DataLoader
import cv2
import time
import pandas_profiling as pdp
from pathlib import Path
from sklearn.model_selection import StratifiedKFold
from utils.util import *
from utils.losses import *
import torch.nn as nn
import transformers as T
import albumentations
import pandas as pd
import cv2
import numpy as np
import timm
import torch.nn as nn
from sklearn import metrics
import torch
from tez.callbacks import EarlyStopping
from tqdm import tqdm
import math
import tez
import torch.optim as optim
import warnings
warnings.simplefilter('ignore')

# %%
class CONFIG:
    DATA_PATH = Path('../input/petfinder-pawpularity-score')
    OUTPUT_DIR = Path('../output/4')
    MODEL_NAME = 'resnet50'
    batch_size = 64
    image_size = 224
    fold = 5
    epoch = 20
    lr = 1e-3
    device='cuda'
    training_step=True
    pretrained=False
    SEED=42
if not os.path.isdir(CONFIG.OUTPUT_DIR):
    os.makedirs(CONFIG.OUTPUT_DIR)
LOGGER = init_logger(OUTPUT_DIR=CONFIG.OUTPUT_DIR)
fix_seed(CONFIG.SEED)

# %%
train_df = pd.read_csv(CONFIG.DATA_PATH / 'train.csv')
train_df['path'] = train_df['Id'].map(lambda x:str(CONFIG.DATA_PATH/'train'/x)+'.jpg')
train_df['image_size'] = train_df['path'].apply(lambda image_id : Image.open(image_id).size)
train_df['width'] = train_df['image_size'].apply(lambda x: x[0])
train_df['height'] = train_df['image_size'].apply(lambda x: x[1])

test_df = pd.read_csv(CONFIG.DATA_PATH / 'test.csv')
test_df['path'] = test_df['Id'].map(lambda x:str(CONFIG.DATA_PATH/'test'/x)+'.jpg')
test_df['image_size'] = test_df['path'].apply(lambda image_id : Image.open(image_id).size)
test_df['width'] = test_df['image_size'].apply(lambda x: x[0])
test_df['height'] = test_df['image_size'].apply(lambda x: x[1])

train_df.head()
# Out:
#                                  Id  Subject Focus  Eyes  Face  Near  Action  \
# 0  0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 1  0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 2  0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 3  0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 4  001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
#
#    Accessory  Group  Collage  Human  Occlusion  Info  Blur  Pawpularity  \
# 0          0      1        0      0          0     0     0           63
# 1          0      0        0      0          0     0     0           42
# 2          0      0        0      1          1     0     0           28
# 3          0      0        0      0          0     0     0           15
# 4          0      1        0      0          0     0     0           72
#
#                                                 path   image_size  width  \
# 0  ../input/petfinder-pawpularity-score/train/000...   (405, 720)    405
# 1  ../input/petfinder-pawpularity-score/train/000...  (1032, 774)   1032
# 2  ../input/petfinder-pawpularity-score/train/001...   (720, 960)    720
# 3  ../input/petfinder-pawpularity-score/train/001...   (405, 720)    405
# 4  ../input/petfinder-pawpularity-score/train/001...   (540, 960)    540
#
#    height
# 0     720
# 1     774
# 2     960
# 3     720
# 4     960

# %%
train_df = get_train_data(train_df, train_df['Pawpularity'], n_splits = CONFIG.fold, regression=True)

# %%
train_aug = albumentations.Compose(
    [
        albumentations.Resize(CONFIG.image_size, CONFIG.image_size, p=1),
        albumentations.Normalize(
            mean=[0.485, 0.456, 0.406],
            std=[0.229, 0.224, 0.225],
            max_pixel_value=255.0,
            p=1.0,
        ),
    ],
    p=1.0,
)

# %%
class PawpularDataset:
    def __init__(self, df, dense_features, targets, augmentations):
        self.image_paths = df['path'].tolist()
        self.dense_features = dense_features
        self.targets = targets
        if self.targets is None:
            self.targets = torch.ones(len(self.image_paths))
        self.augmentations = augmentations
        
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, item):
        image = cv2.imread(self.image_paths[item])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        if self.augmentations is not None:
            augmented = self.augmentations(image=image)
            image = augmented["image"]
        targets = self.targets[item]
        image = np.transpose(image, (2, 0, 1)).astype(np.float32)
        
        features = self.dense_features[item, :]
        
        return {
            "image": torch.tensor(image, dtype=torch.float),
            "features": torch.tensor(features, dtype=torch.float),
            "targets": torch.tensor(targets, dtype=torch.float)
        }

# %%
class PawpularModel(nn.Module):
    def __init__(self, model_name):
        super().__init__()
        self.model = timm.create_model(model_name, pretrained=CONFIG.pretrained, in_chans=3)
        self.model.fc = nn.Linear(self.model.fc.in_features, 128)
        self.dropout = nn.Dropout(0.1)
        self.dense1 = nn.Linear(140, 64)
        self.dense2 = nn.Linear(64, 1)

    def forward(self, image, features):
        x = self.model(image)
        x = self.dropout(x)
        x = torch.cat([x, features], dim=1)
        x = self.dense1(x)
        x = self.dense2(x)
        return torch.sigmoid(x.squeeze(1))

# %%
def train_fn(train_loader, model, criterion, optimizer, batch_size, epoch, device):
    start = end = time.time()
    losses = AverageMeter()
    model.train()
    for iter, data in tqdm(enumerate(train_loader), total=len(train_loader)):
        optimizer.zero_grad()
        img, feature ,target = data['image'], data['features'], data['targets']
        img = img.to(device)
        feature = feature.to(device)
        target = target.to(device)
        y_preds = model(img, feature)
        loss = criterion(y_preds, target)
        # record loss
        losses.update(loss.item(), batch_size)
        loss.backward()
        optimizer.step()

    return losses.avg

def valid_fn(valid_loader, model, criterion, device):
    start = end = time.time()
    losses = AverageMeter()

    # switch to evaluation mode
    model.eval()
    preds = []

    for iter, data in enumerate(valid_loader):
        img, feature ,target = data['image'], data['features'], data['targets']
        img = img.to(device)
        feature = feature.to(device)
        target = target.to(device)
        batch_size = target.size(0)

        # compute loss
        with torch.no_grad():
            y_preds = model(img, feature)

        loss = criterion(y_preds, target)
        losses.update(loss.item(), batch_size)

        # record score
        preds.append(y_preds.to("cpu").numpy())

    predictions = np.concatenate(preds)
    return losses.avg, predictions

# %%
def train_loop(train, fold_):
    LOGGER.info(f"========== fold: {fold_} training ==========")

    # ====================================================
    # Data Loader
    # ====================================================
    model = PawpularModel(model_name=CONFIG.MODEL_NAME)
    model.to(CONFIG.device)
    if torch.cuda.device_count()>1:
        model=nn.DataParallel(model)
    dense_features = [
        'Subject Focus', 'Eyes', 'Face', 'Near', 'Action', 'Accessory',
        'Group', 'Collage', 'Human', 'Occlusion', 'Info', 'Blur'
    ]
    train_idx = train[train.fold!=fold_].index
    val_idx = train[train.fold ==fold_].index
    train_folds = train.loc[train_idx].reset_index(drop=True)
    valid_folds = train.loc[val_idx].reset_index(drop=True)
    train_dataset = PawpularDataset(
        train_folds, 
        dense_features=train_folds[dense_features].values, targets=train_folds['Pawpularity']/100,
        augmentations=train_aug,
    )
    
    val_dataset = PawpularDataset(
        valid_folds, 
        dense_features=valid_folds[dense_features].values, targets=valid_folds['Pawpularity']/100,
        augmentations=train_aug,
    )
    train_loader = DataLoader(
        train_dataset,
        batch_size=CONFIG.batch_size,
        shuffle=True,
        pin_memory=True,
        drop_last=True,
    )
    valid_loader = DataLoader(
        val_dataset,
        batch_size=CONFIG.batch_size,
        shuffle=False,
        pin_memory=True,
        drop_last=False,
    )

    optimizer = optim.Adam(model.parameters(), lr=CONFIG.lr)
    
    criterion = nn.MSELoss()
    metric = RMSE()
    best_score = np.inf
    best_loss = np.inf
    
    for epoch in range(CONFIG.epoch):
        start_time = time.time()
        # train
        avg_loss = train_fn(train_loader, model, criterion, optimizer, CONFIG.batch_size, epoch, CONFIG.device)
#        # eval
        avg_val_loss, preds = valid_fn(valid_loader, model, criterion, CONFIG.device)
        valid_labels = torch.tensor(valid_folds["Pawpularity"].values).float()
        score = metric(preds * 100, valid_labels)
        elapsed = time.time() - start_time
        
        LOGGER.info(
            f"Epoch {epoch+1} - avg_train_loss: {avg_loss:.4f}  avg_val_loss: {avg_val_loss:.4f}  time: {elapsed:.0f}s"
        )
        LOGGER.info(f"Epoch {epoch+1} - Score: {score}")
        if score < best_score:
            best_score = score
            LOGGER.info(f"Epoch {epoch+1} - Save Best Score: {best_score:.4f} Model")
            torch.save(
                {"model": model.state_dict(), "preds": preds * 100}, CONFIG.OUTPUT_DIR / f"{CONFIG.MODEL_NAME}_{fold_}_best.pth")
    check_point = torch.load(CONFIG.OUTPUT_DIR / f"{CONFIG.MODEL_NAME}_{fold_}_best.pth")

    valid_folds["preds"] = check_point["preds"]

    return valid_folds

# %%
def get_result(result_df):
    metric = RMSE()
    preds = result_df["Pawpularity"].values
    labels = result_df["preds"].values
    score = metric(preds, labels)
    LOGGER.info(f"Score: {score:<.5f}")

# %%
def inference():
    predictions = []
    dense_features = [
        'Subject Focus', 'Eyes', 'Face', 'Near', 'Action', 'Accessory',
        'Group', 'Collage', 'Human', 'Occlusion', 'Info', 'Blur'
    ]
    test_dataset = PawpularDataset(
        test_df, 
        dense_features=test_df[dense_features].values, targets=None,
        augmentations=train_aug,
    )
    test_loader = DataLoader(
        test_dataset, batch_size=16, shuffle=False, num_workers=4, pin_memory=True
    )

    for fold in range(5):
        LOGGER.info(f"========== model: {CONFIG.MODEL_NAME} fold: {fold} inference ==========")
        model = PawpularModel(model_name=CONFIG.MODEL_NAME)
        model.to(CONFIG.device)
        if torch.cuda.device_count()>1:
            model=nn.DataParallel(model)
            model.load_state_dict(torch.load(CONFIG.OUTPUT_DIR / f"{CONFIG.MODEL_NAME}_{fold}_best.pth")["model"])
        else:
            model.load_state_dict(fix_model_state_dict(torch.load(CONFIG.OUTPUT_DIR / f"{CONFIG.MODEL_NAME}_{fold}_best.pth")["model"]))
        model.eval()
        preds = []
        for i, data in tqdm(enumerate(test_loader), total=len(test_loader)):
            img, feature ,target = data['image'], data['features'], data['targets']
            img = img.to(CONFIG.device)
            feature = feature.to(CONFIG.device)
            target = target.to(CONFIG.device)
            with torch.no_grad():
                y_preds = model(img, feature)
            preds.append(y_preds.to("cpu").numpy())
        preds = np.concatenate(preds)
        predictions.append(preds)
    predictions = np.mean(predictions, axis=0)
    return predictions * 100

# %%
def main():
    # Training
    oof_df = pd.DataFrame()
    if CONFIG.training_step:
        for fold in range(CONFIG.fold):
            _oof_df = train_loop(train_df, fold)
            oof_df = pd.concat([oof_df, _oof_df])
            LOGGER.info(f"========== fold: {fold} result ==========")
            get_result(_oof_df)
        # Save OOF result
        oof_df.to_csv(CONFIG.OUTPUT_DIR / "oof_df.csv", index=False)
    else:
        oof_df = pd.read_csv(CONFIG.OUTPUT_DIR / "oof_df.csv")
    # CV result
    LOGGER.info(f"========== CV ==========")
    get_result(oof_df)
    # Inference
    predictions = inference()
    # submission
    submission = test_df.copy()
    submission["Pawpularity"] = predictions
    submission = submission[["Id", "Pawpularity"]]
    submission.to_csv(CONFIG.OUTPUT_DIR / "submission.csv", index=False)

# %%
if __name__ == "__main__":
    main()
# Out:
# ========== fold: 0 training ==========
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:20<00:00,  1.52it/s]
# Epoch 1 - avg_train_loss: 0.0453  avg_val_loss: 0.0434  time: 97s
# Epoch 1 - Score: 20.83193588256836
# Epoch 1 - Save Best Score: 20.8319 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 2 - avg_train_loss: 0.0425  avg_val_loss: 0.0435  time: 96s
# Epoch 2 - Score: 20.852209091186523
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 3 - avg_train_loss: 0.0424  avg_val_loss: 0.0435  time: 95s
# Epoch 3 - Score: 20.848527908325195
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 4 - avg_train_loss: 0.0424  avg_val_loss: 0.0436  time: 95s
# Epoch 4 - Score: 20.887989044189453
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 5 - avg_train_loss: 0.0423  avg_val_loss: 0.0428  time: 96s
# Epoch 5 - Score: 20.6840763092041
# Epoch 5 - Save Best Score: 20.6841 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 6 - avg_train_loss: 0.0421  avg_val_loss: 0.0427  time: 95s
# Epoch 6 - Score: 20.662675857543945
# Epoch 6 - Save Best Score: 20.6627 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 7 - avg_train_loss: 0.0421  avg_val_loss: 0.0428  time: 95s
# Epoch 7 - Score: 20.699655532836914
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 8 - avg_train_loss: 0.0423  avg_val_loss: 0.0429  time: 96s
# Epoch 8 - Score: 20.723552703857422
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 9 - avg_train_loss: 0.0417  avg_val_loss: 0.0436  time: 95s
# Epoch 9 - Score: 20.871686935424805
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 10 - avg_train_loss: 0.0418  avg_val_loss: 0.0430  time: 95s
# Epoch 10 - Score: 20.74120330810547
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 11 - avg_train_loss: 0.0415  avg_val_loss: 0.0429  time: 96s
# Epoch 11 - Score: 20.70754623413086
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 12 - avg_train_loss: 0.0415  avg_val_loss: 0.0428  time: 96s
# Epoch 12 - Score: 20.699447631835938
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.56it/s]
# Epoch 13 - avg_train_loss: 0.0413  avg_val_loss: 0.0426  time: 95s
# Epoch 13 - Score: 20.64670753479004
# Epoch 13 - Save Best Score: 20.6467 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 14 - avg_train_loss: 0.0408  avg_val_loss: 0.0432  time: 95s
# Epoch 14 - Score: 20.787879943847656
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 15 - avg_train_loss: 0.0402  avg_val_loss: 0.0433  time: 96s
# Epoch 15 - Score: 20.814393997192383
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 16 - avg_train_loss: 0.0393  avg_val_loss: 0.0459  time: 96s
# Epoch 16 - Score: 21.435165405273438
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 17 - avg_train_loss: 0.0383  avg_val_loss: 0.0452  time: 95s
# Epoch 17 - Score: 21.251827239990234
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 18 - avg_train_loss: 0.0368  avg_val_loss: 0.0479  time: 96s
# Epoch 18 - Score: 21.87514305114746
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 19 - avg_train_loss: 0.0358  avg_val_loss: 0.0455  time: 95s
# Epoch 19 - Score: 21.31975746154785
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 20 - avg_train_loss: 0.0339  avg_val_loss: 0.0463  time: 95s
# Epoch 20 - Score: 21.522199630737305
# ========== fold: 0 result ==========
# Score: 20.64671
# ========== fold: 1 training ==========
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 1 - avg_train_loss: 0.0450  avg_val_loss: 0.0435  time: 96s
# Epoch 1 - Score: 20.85305404663086
# Epoch 1 - Save Best Score: 20.8531 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 2 - avg_train_loss: 0.0424  avg_val_loss: 0.0428  time: 96s
# Epoch 2 - Score: 20.6806697845459
# Epoch 2 - Save Best Score: 20.6807 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 3 - avg_train_loss: 0.0427  avg_val_loss: 0.0428  time: 95s
# Epoch 3 - Score: 20.69167709350586
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:18<00:00,  1.56it/s]
# Epoch 4 - avg_train_loss: 0.0426  avg_val_loss: 0.0427  time: 96s
# Epoch 4 - Score: 20.670597076416016
# Epoch 4 - Save Best Score: 20.6706 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 5 - avg_train_loss: 0.0425  avg_val_loss: 0.0436  time: 96s
# Epoch 5 - Score: 20.869516372680664
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:18<00:00,  1.56it/s]
# Epoch 6 - avg_train_loss: 0.0423  avg_val_loss: 0.0429  time: 95s
# Epoch 6 - Score: 20.70597267150879
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 7 - avg_train_loss: 0.0424  avg_val_loss: 0.0427  time: 96s
# Epoch 7 - Score: 20.671804428100586
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 8 - avg_train_loss: 0.0421  avg_val_loss: 0.0428  time: 96s
# Epoch 8 - Score: 20.678007125854492
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 9 - avg_train_loss: 0.0420  avg_val_loss: 0.0429  time: 96s
# Epoch 9 - Score: 20.706594467163086
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 10 - avg_train_loss: 0.0419  avg_val_loss: 0.0427  time: 96s
# Epoch 10 - Score: 20.664926528930664
# Epoch 10 - Save Best Score: 20.6649 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 11 - avg_train_loss: 0.0419  avg_val_loss: 0.0433  time: 96s
# Epoch 11 - Score: 20.800384521484375
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 12 - avg_train_loss: 0.0416  avg_val_loss: 0.0428  time: 96s
# Epoch 12 - Score: 20.690427780151367
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 13 - avg_train_loss: 0.0415  avg_val_loss: 0.0440  time: 96s
# Epoch 13 - Score: 20.97834014892578
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 14 - avg_train_loss: 0.0414  avg_val_loss: 0.0429  time: 96s
# Epoch 14 - Score: 20.716590881347656
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 15 - avg_train_loss: 0.0408  avg_val_loss: 0.0446  time: 96s
# Epoch 15 - Score: 21.123994827270508
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.56it/s]
# Epoch 16 - avg_train_loss: 0.0405  avg_val_loss: 0.0438  time: 95s
# Epoch 16 - Score: 20.92885971069336
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.56it/s]
# Epoch 17 - avg_train_loss: 0.0397  avg_val_loss: 0.0443  time: 96s
# Epoch 17 - Score: 21.04119110107422
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 18 - avg_train_loss: 0.0388  avg_val_loss: 0.0445  time: 96s
# Epoch 18 - Score: 21.089202880859375
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 19 - avg_train_loss: 0.0369  avg_val_loss: 0.0476  time: 95s
# Epoch 19 - Score: 21.809492111206055
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 20 - avg_train_loss: 0.0356  avg_val_loss: 0.0483  time: 96s
# Epoch 20 - Score: 21.972070693969727
# ========== fold: 1 result ==========
# Score: 20.66493
# ========== fold: 2 training ==========
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 1 - avg_train_loss: 0.0461  avg_val_loss: 0.0425  time: 96s
# Epoch 1 - Score: 20.60951042175293
# Epoch 1 - Save Best Score: 20.6095 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:18<00:00,  1.56it/s]
# Epoch 2 - avg_train_loss: 0.0435  avg_val_loss: 0.0436  time: 95s
# Epoch 2 - Score: 20.87200927734375
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 3 - avg_train_loss: 0.0433  avg_val_loss: 0.0421  time: 96s
# Epoch 3 - Score: 20.509075164794922
# Epoch 3 - Save Best Score: 20.5091 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 4 - avg_train_loss: 0.0428  avg_val_loss: 0.0419  time: 96s
# Epoch 4 - Score: 20.468656539916992
# Epoch 4 - Save Best Score: 20.4687 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 5 - avg_train_loss: 0.0426  avg_val_loss: 0.0426  time: 96s
# Epoch 5 - Score: 20.64564323425293
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.56it/s]
# Epoch 6 - avg_train_loss: 0.0428  avg_val_loss: 0.0419  time: 95s
# Epoch 6 - Score: 20.467235565185547
# Epoch 6 - Save Best Score: 20.4672 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 7 - avg_train_loss: 0.0427  avg_val_loss: 0.0421  time: 96s
# Epoch 7 - Score: 20.51201629638672
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 8 - avg_train_loss: 0.0426  avg_val_loss: 0.0418  time: 96s
# Epoch 8 - Score: 20.445322036743164
# Epoch 8 - Save Best Score: 20.4453 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 9 - avg_train_loss: 0.0426  avg_val_loss: 0.0418  time: 96s
# Epoch 9 - Score: 20.450998306274414
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 10 - avg_train_loss: 0.0423  avg_val_loss: 0.0432  time: 96s
# Epoch 10 - Score: 20.786251068115234
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 11 - avg_train_loss: 0.0423  avg_val_loss: 0.0420  time: 96s
# Epoch 11 - Score: 20.500879287719727
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.56it/s]
# Epoch 12 - avg_train_loss: 0.0423  avg_val_loss: 0.0421  time: 95s
# Epoch 12 - Score: 20.51552391052246
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 13 - avg_train_loss: 0.0421  avg_val_loss: 0.0421  time: 96s
# Epoch 13 - Score: 20.51520538330078
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 14 - avg_train_loss: 0.0421  avg_val_loss: 0.0421  time: 96s
# Epoch 14 - Score: 20.521259307861328
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 15 - avg_train_loss: 0.0417  avg_val_loss: 0.0419  time: 95s
# Epoch 15 - Score: 20.466121673583984
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 16 - avg_train_loss: 0.0418  avg_val_loss: 0.0420  time: 95s
# Epoch 16 - Score: 20.491188049316406
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 17 - avg_train_loss: 0.0412  avg_val_loss: 0.0421  time: 96s
# Epoch 17 - Score: 20.51630973815918
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 18 - avg_train_loss: 0.0408  avg_val_loss: 0.0425  time: 96s
# Epoch 18 - Score: 20.61409568786621
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.56it/s]
# Epoch 19 - avg_train_loss: 0.0400  avg_val_loss: 0.0423  time: 95s
# Epoch 19 - Score: 20.5704402923584
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 20 - avg_train_loss: 0.0387  avg_val_loss: 0.0430  time: 96s
# Epoch 20 - Score: 20.732166290283203
# ========== fold: 2 result ==========
# Score: 20.44532
# ========== fold: 3 training ==========
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 1 - avg_train_loss: 0.0453  avg_val_loss: 0.0431  time: 95s
# Epoch 1 - Score: 20.761598587036133
# Epoch 1 - Save Best Score: 20.7616 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 2 - avg_train_loss: 0.0426  avg_val_loss: 0.0430  time: 95s
# Epoch 2 - Score: 20.731670379638672
# Epoch 2 - Save Best Score: 20.7317 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 3 - avg_train_loss: 0.0425  avg_val_loss: 0.0428  time: 96s
# Epoch 3 - Score: 20.688283920288086
# Epoch 3 - Save Best Score: 20.6883 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 4 - avg_train_loss: 0.0425  avg_val_loss: 0.0428  time: 96s
# Epoch 4 - Score: 20.678565979003906
# Epoch 4 - Save Best Score: 20.6786 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 5 - avg_train_loss: 0.0423  avg_val_loss: 0.0429  time: 95s
# Epoch 5 - Score: 20.719749450683594
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 6 - avg_train_loss: 0.0424  avg_val_loss: 0.0440  time: 96s
# Epoch 6 - Score: 20.97861671447754
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 7 - avg_train_loss: 0.0421  avg_val_loss: 0.0427  time: 96s
# Epoch 7 - Score: 20.664649963378906
# Epoch 7 - Save Best Score: 20.6646 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 8 - avg_train_loss: 0.0420  avg_val_loss: 0.0427  time: 95s
# Epoch 8 - Score: 20.655122756958008
# Epoch 8 - Save Best Score: 20.6551 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 9 - avg_train_loss: 0.0421  avg_val_loss: 0.0427  time: 95s
# Epoch 9 - Score: 20.671310424804688
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 10 - avg_train_loss: 0.0421  avg_val_loss: 0.0428  time: 96s
# Epoch 10 - Score: 20.69108009338379
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 11 - avg_train_loss: 0.0420  avg_val_loss: 0.0428  time: 95s
# Epoch 11 - Score: 20.67804527282715
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 12 - avg_train_loss: 0.0417  avg_val_loss: 0.0427  time: 96s
# Epoch 12 - Score: 20.656362533569336
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 13 - avg_train_loss: 0.0416  avg_val_loss: 0.0431  time: 96s
# Epoch 13 - Score: 20.75257682800293
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 14 - avg_train_loss: 0.0414  avg_val_loss: 0.0432  time: 96s
# Epoch 14 - Score: 20.78164291381836
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 15 - avg_train_loss: 0.0409  avg_val_loss: 0.0439  time: 95s
# Epoch 15 - Score: 20.9534969329834
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 16 - avg_train_loss: 0.0404  avg_val_loss: 0.0449  time: 96s
# Epoch 16 - Score: 21.185440063476562
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 17 - avg_train_loss: 0.0397  avg_val_loss: 0.0435  time: 96s
# Epoch 17 - Score: 20.84940528869629
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 18 - avg_train_loss: 0.0392  avg_val_loss: 0.0462  time: 95s
# Epoch 18 - Score: 21.484939575195312
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 19 - avg_train_loss: 0.0378  avg_val_loss: 0.0447  time: 95s
# Epoch 19 - Score: 21.139440536499023
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 20 - avg_train_loss: 0.0365  avg_val_loss: 0.0462  time: 96s
# Epoch 20 - Score: 21.505117416381836
# ========== fold: 3 result ==========
# Score: 20.65512
# ========== fold: 4 training ==========
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 1 - avg_train_loss: 0.0458  avg_val_loss: 0.0420  time: 95s
# Epoch 1 - Score: 20.496253967285156
# Epoch 1 - Save Best Score: 20.4963 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 2 - avg_train_loss: 0.0433  avg_val_loss: 0.0422  time: 95s
# Epoch 2 - Score: 20.535043716430664
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:20<00:00,  1.53it/s]
# Epoch 3 - avg_train_loss: 0.0429  avg_val_loss: 0.0419  time: 96s
# Epoch 3 - Score: 20.477230072021484
# Epoch 3 - Save Best Score: 20.4772 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 4 - avg_train_loss: 0.0429  avg_val_loss: 0.0427  time: 95s
# Epoch 4 - Score: 20.668230056762695
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 5 - avg_train_loss: 0.0427  avg_val_loss: 0.0423  time: 95s
# Epoch 5 - Score: 20.555095672607422
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 6 - avg_train_loss: 0.0426  avg_val_loss: 0.0422  time: 96s
# Epoch 6 - Score: 20.547693252563477
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 7 - avg_train_loss: 0.0425  avg_val_loss: 0.0437  time: 96s
# Epoch 7 - Score: 20.9022274017334
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 8 - avg_train_loss: 0.0425  avg_val_loss: 0.0433  time: 95s
# Epoch 8 - Score: 20.807662963867188
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 9 - avg_train_loss: 0.0427  avg_val_loss: 0.0419  time: 96s
# Epoch 9 - Score: 20.474071502685547
# Epoch 9 - Save Best Score: 20.4741 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 10 - avg_train_loss: 0.0425  avg_val_loss: 0.0424  time: 96s
# Epoch 10 - Score: 20.5927734375
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 11 - avg_train_loss: 0.0423  avg_val_loss: 0.0421  time: 95s
# Epoch 11 - Score: 20.5073184967041
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 12 - avg_train_loss: 0.0422  avg_val_loss: 0.0419  time: 95s
# Epoch 12 - Score: 20.460447311401367
# Epoch 12 - Save Best Score: 20.4604 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 13 - avg_train_loss: 0.0420  avg_val_loss: 0.0418  time: 96s
# Epoch 13 - Score: 20.454654693603516
# Epoch 13 - Save Best Score: 20.4547 Model
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 14 - avg_train_loss: 0.0419  avg_val_loss: 0.0420  time: 95s
# Epoch 14 - Score: 20.495811462402344
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 15 - avg_train_loss: 0.0415  avg_val_loss: 0.0420  time: 95s
# Epoch 15 - Score: 20.48613166809082
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 16 - avg_train_loss: 0.0414  avg_val_loss: 0.0431  time: 96s
# Epoch 16 - Score: 20.761579513549805
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 17 - avg_train_loss: 0.0413  avg_val_loss: 0.0426  time: 96s
# Epoch 17 - Score: 20.635244369506836
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 18 - avg_train_loss: 0.0406  avg_val_loss: 0.0431  time: 96s
# Epoch 18 - Score: 20.754566192626953
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.54it/s]
# Epoch 19 - avg_train_loss: 0.0398  avg_val_loss: 0.0433  time: 96s
# Epoch 19 - Score: 20.814228057861328
# 100%|█████████████████████████████████████████████████████████████| 123/123 [01:19<00:00,  1.55it/s]
# Epoch 20 - avg_train_loss: 0.0391  avg_val_loss: 0.0464  time: 96s
# Epoch 20 - Score: 21.547744750976562
# ========== fold: 4 result ==========
# Score: 20.45465
# ========== CV ==========
# Score: 20.57361
# ========== model: resnet50 fold: 0 inference ==========
# 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.60it/s]
# ========== model: resnet50 fold: 1 inference ==========
# 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.81it/s]
# ========== model: resnet50 fold: 2 inference ==========
# 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.76it/s]
# ========== model: resnet50 fold: 3 inference ==========
# 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.64it/s]
# ========== model: resnet50 fold: 4 inference ==========
# 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.61it/s]
